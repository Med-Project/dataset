# %%
import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import os

import os
import pandas as pd
import numpy as np
from gensim.corpora.wikicorpus import WikiCorpus
from gensim.models.word2vec import Word2Vec, LineSentence
from pprint import pprint
from copy import deepcopy
from multiprocessing import cpu_count
import gensim
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

from tqdm import tqdm

from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords

from sklearn.manifold import TSNE
from sklearn import cluster

import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from bokeh.io import output_notebook
from bokeh.palettes import viridis
from bokeh.plotting import figure, show, output_file, save
from bokeh.models import HoverTool, CategoricalColorMapper
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label

# %matplotlib inline
output_notebook()
# Out:
# WARNING:tensorflow:From /Users/sanzhar/.virtualenvs/ml/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2e504d9a-ed62-48b4-b0aa-17307b9cc094">Loading BokehJS ...</span>
#     </div>

# %%
class SiameseNetwork:
    def __init__(self):
        self.x1 = tf.placeholder(tf.float32, [None, 250])
        self.x2 = tf.placeholder(tf.float32, [None, 250])

        with tf.variable_scope("siamese") as scope:
            self.o1 = self.network(self.x1)
            scope.reuse_variables()
            self.o2 = self.network(self.x2)
        
        self.y_ = tf.placeholder(tf.float32, [None])
        self.loss = self.loss_with_spring()

    def network(self, x):
        weights = []
        fc1 = self.fc_layer(x, 128, "fc1")
        ac1 = tf.nn.relu(fc1)
        fc2 = self.fc_layer(ac1, 64, "fc2")
        ac2 = tf.nn.relu(fc2)
        fc3 = self.fc_layer(ac2, 3, "fc3")
        return fc3

    def fc_layer(self, bottom, n_weight, name):
        assert len(bottom.get_shape()) == 2
        n_prev_weight = bottom.get_shape()[1]
        initer = tf.truncated_normal_initializer(stddev=0.01)
        W = tf.get_variable(name+'W', dtype=tf.float32, shape=[n_prev_weight, n_weight], initializer=initer)
        b = tf.get_variable(name+'b', dtype=tf.float32, initializer=tf.constant(0.01, shape=[n_weight], dtype=tf.float32))
        fc = tf.nn.bias_add(tf.matmul(bottom, W), b)
        return fc

    def loss_with_spring(self):
        margin = 5.0
        labels_t = self.y_
        labels_f = tf.subtract(1.0, self.y_, name="1-yi")
        eucd2 = tf.pow(tf.subtract(self.o1, self.o2), 2)
        eucd2 = tf.reduce_sum(eucd2, 1)
        eucd = tf.sqrt(eucd2+1e-6, name="eucd")
        C = tf.constant(margin, name="C")
        # yi*||CNN(p1i)-CNN(p2i)||^2 + (1-yi)*max(0, C-||CNN(p1i)-CNN(p2i)||^2)
        pos = tf.multiply(labels_t, eucd2, name="yi_x_eucd2")
        # neg = tf.multiply(labels_f, tf.subtract(0.0,eucd2), name="yi_x_eucd2")
        # neg = tf.multiply(labels_f, tf.maximum(0.0, tf.subtract(C,eucd2)), name="Nyi_x_C-eucd_xx_2")
        neg = tf.multiply(labels_f, tf.pow(tf.maximum(tf.subtract(C, eucd), 0), 2), name="Nyi_x_C-eucd_xx_2")
        losses = tf.add(pos, neg, name="losses")
        loss = tf.reduce_mean(losses, name="loss")
        return loss

    def loss_with_step(self):
        margin = 5.0
        labels_t = self.y_
        labels_f = tf.subtract(1.0, self.y_, name="1-yi")          # labels_ = !labels;
        eucd2 = tf.pow(tf.subtract(self.o1, self.o2), 2)
        eucd2 = tf.reduce_sum(eucd2, 1)
        eucd = tf.sqrt(eucd2+1e-6, name="eucd")
        C = tf.constant(margin, name="C")
        pos = tf.multiply(labels_t, eucd, name="y_x_eucd")
        neg = tf.multiply(labels_f, tf.maximum(0.0, tf.subtract(C, eucd)), name="Ny_C-eucd")
        losses = tf.add(pos, neg, name="losses")
        loss = tf.reduce_mean(losses, name="loss")
        return loss

# %% [markdown]
# ## Data

# %%
X_topic = []
Y_topic = []

X_path = 'topic_vectors.txt'
Y_path = 'topic_names.txt'

if(os.path.isfile(X_path) and os.path.isfile(Y_path)):
    print('load from .txt file')
    X_topic = np.loadtxt(X_path)
    with open(Y_path, 'r') as f:
        for line in f.readlines():
            Y_topic.append(line.replace('\n',''))
    Y_topic = np.array(Y_topic)
# Out:
# load from .txt file

# %%
bolezni = pd.read_csv('../parse-html/bolezni.csv')
X_categ = []
for i in bolezni['topics']:
    toks = i.split(' $ ')
    X_categ.append(toks[0])
X_categ = np.array(X_categ)

name2topic = {}
for i in range(X_topic.shape[0]):
    name2topic[str(Y_topic[i])] = str(X_categ[i])

# %%
name2vector = {}
for i in range(X_topic.shape[0]):
    name2vector[str(Y_topic[i])] = X_topic[i]

# %%
siamese_data = pd.read_csv('siamese_data.csv')

# %%
emb_size = 250
X = np.zeros((siamese_data.shape[0], 2, emb_size))
y = np.array(siamese_data['target'].values)

# %%
for d, i in siamese_data.iterrows():
    X[d, 0, :] = name2vector[i[0]]
    X[d, 1, :] = name2vector[i[1]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((40270, 2, 250), (19835, 2, 250), (40270,), (19835,))

# %%
np.bincount(y_train), np.bincount(y_test)
# Out:
# (array([37881,  2389]), array([18659,  1176]))

# %% [markdown]
# ## Model

# %%
sess = tf.InteractiveSession()

# %%
siamese = SiameseNetwork()

# %%
train_step = tf.train.AdamOptimizer(0.001).minimize(siamese.loss)
saver = tf.train.Saver()
tf.global_variables_initializer().run()

# %%
for step in range(10000):
    _, loss_v = sess.run([train_step, siamese.loss], feed_dict={
                        siamese.x1: X[:,0,:],
                        siamese.x2: X[:,1,:],
                        siamese.y_: y})

    if np.isnan(loss_v):
        print('Model diverged with loss = NaN')
        quit()

    if(step % 10 == 0):
        print('step %d: loss %.3f' % (step, loss_v))

    if(step % 1000 == 0 and step > 0):
        saver.save(sess, './model')
#         embed = siamese.o1.eval({siamese.x1: mnist.test.images})
#         embed.tofile('embed.txt')
# Out:
# step 0: loss 23.507
# step 10: loss 22.575
# step 20: loss 16.291
# step 30: loss 6.739
# step 40: loss 5.951
# step 50: loss 5.725
# step 60: loss 5.240
# step 70: loss 4.560
# step 80: loss 3.466
# step 90: loss 2.936
# step 100: loss 2.885
# step 110: loss 2.806
# step 120: loss 2.723
# step 130: loss 2.663
# step 140: loss 2.603
# step 150: loss 2.547
# step 160: loss 2.497
# step 170: loss 2.455
# step 180: loss 2.420
# step 190: loss 2.389
# step 200: loss 2.359
# step 210: loss 2.328
# step 220: loss 2.296
# step 230: loss 2.264
# step 240: loss 2.232
# step 250: loss 2.202
# step 260: loss 2.176
# step 270: loss 2.152
# step 280: loss 2.131
# step 290: loss 2.113
# step 300: loss 2.095
# step 310: loss 2.077
# step 320: loss 2.058
# step 330: loss 2.037
# step 340: loss 2.016
# step 350: loss 1.994
# step 360: loss 1.973
# step 370: loss 1.952
# step 380: loss 1.932
# step 390: loss 1.912
# step 400: loss 1.891
# step 410: loss 1.872
# step 420: loss 1.852
# step 430: loss 1.832
# step 440: loss 1.811
# step 450: loss 1.787
# step 460: loss 1.757
# step 470: loss 1.715
# step 480: loss 1.648
# step 490: loss 1.552
# step 500: loss 1.481
# step 510: loss 1.450
# step 520: loss 1.428
# step 530: loss 1.408
# step 540: loss 1.391
# step 550: loss 1.374
# step 560: loss 1.358
# step 570: loss 1.342
# step 580: loss 1.327
# step 590: loss 1.312
# step 600: loss 1.297
# step 610: loss 1.282
# step 620: loss 1.267
# step 630: loss 1.253
# step 640: loss 1.239
# step 650: loss 1.225
# step 660: loss 1.211
# step 670: loss 1.199
# step 680: loss 1.186
# step 690: loss 1.175
# step 700: loss 1.164
# step 710: loss 1.153
# step 720: loss 1.143
# step 730: loss 1.133
# step 740: loss 1.124
# step 750: loss 1.115
# step 760: loss 1.106
# step 770: loss 1.097
# step 780: loss 1.088
# step 790: loss 1.079
# step 800: loss 1.071
# step 810: loss 1.062
# step 820: loss 1.054
# step 830: loss 1.045
# step 840: loss 1.037
# step 850: loss 1.028
# step 860: loss 1.020
# step 870: loss 1.012
# step 880: loss 1.003
# step 890: loss 0.995
# step 900: loss 0.987
# step 910: loss 0.978
# step 920: loss 0.970
# step 930: loss 0.962
# step 940: loss 0.954
# step 950: loss 0.946
# step 960: loss 0.938
# step 970: loss 0.930
# step 980: loss 0.922
# step 990: loss 0.914
# step 1000: loss 0.906
# step 1010: loss 0.899
# step 1020: loss 0.891
# step 1030: loss 0.884
# step 1040: loss 0.876
# step 1050: loss 0.868
# step 1060: loss 0.861
# step 1070: loss 0.854
# step 1080: loss 0.846
# step 1090: loss 0.839
# step 1100: loss 0.831
# step 1110: loss 0.824
# step 1120: loss 0.816
# step 1130: loss 0.809
# step 1140: loss 0.801
# step 1150: loss 0.793
# step 1160: loss 0.785
# step 1170: loss 0.777
# step 1180: loss 0.769
# step 1190: loss 0.761
# step 1200: loss 0.754
# step 1210: loss 0.746
# step 1220: loss 0.738
# step 1230: loss 0.730
# step 1240: loss 0.722
# step 1250: loss 0.714
# step 1260: loss 0.707
# step 1270: loss 0.699
# step 1280: loss 0.691
# step 1290: loss 0.684
# step 1300: loss 0.676
# step 1310: loss 0.668
# step 1320: loss 0.661
# step 1330: loss 0.653
# step 1340: loss 0.646
# step 1350: loss 0.639
# step 1360: loss 0.631
# step 1370: loss 0.624
# step 1380: loss 0.617
# step 1390: loss 0.609
# step 1400: loss 0.602
# step 1410: loss 0.595
# step 1420: loss 0.588
# step 1430: loss 0.581
# step 1440: loss 0.574
# step 1450: loss 0.567
# step 1460: loss 0.560
# step 1470: loss 0.554
# step 1480: loss 0.547
# step 1490: loss 0.540
# step 1500: loss 0.533
# step 1510: loss 0.526
# step 1520: loss 0.520
# step 1530: loss 0.513
# step 1540: loss 0.506
# step 1550: loss 0.499
# step 1560: loss 0.493
# step 1570: loss 0.486
# step 1580: loss 0.479
# step 1590: loss 0.473
# step 1600: loss 0.467
# step 1610: loss 0.460
# step 1620: loss 0.454
# step 1630: loss 0.448
# step 1640: loss 0.442
# step 1650: loss 0.436
# step 1660: loss 0.430
# step 1670: loss 0.424
# step 1680: loss 0.418
# step 1690: loss 0.412
# step 1700: loss 0.407
# step 1710: loss 0.401
# step 1720: loss 0.396
# step 1730: loss 0.390
# step 1740: loss 0.385
# step 1750: loss 0.379
# step 1760: loss 0.374
# step 1770: loss 0.369
# step 1780: loss 0.364
# step 1790: loss 0.358
# step 1800: loss 0.354
# step 1810: loss 0.349
# step 1820: loss 0.344
# step 1830: loss 0.339
# step 1840: loss 0.334
# step 1850: loss 0.330
# step 1860: loss 0.325
# step 1870: loss 0.321
# step 1880: loss 0.316
# step 1890: loss 0.312
# step 1900: loss 0.308
# step 1910: loss 0.303
# step 1920: loss 0.299
# step 1930: loss 0.295
# step 1940: loss 0.291
# step 1950: loss 0.287
# step 1960: loss 0.283
# step 1970: loss 0.279
# step 1980: loss 0.275
# step 1990: loss 0.271
# step 2000: loss 0.268
# step 2010: loss 0.264
# step 2020: loss 0.260
# step 2030: loss 0.257
# step 2040: loss 0.253
# step 2050: loss 0.250
# step 2060: loss 0.247
# step 2070: loss 0.244
# step 2080: loss 0.241
# step 2090: loss 0.237
# step 2100: loss 0.234
# step 2110: loss 0.231
# step 2120: loss 0.228
# step 2130: loss 0.226
# step 2140: loss 0.222
# step 2150: loss 0.220
# step 2160: loss 0.218
# step 2170: loss 0.214
# step 2180: loss 0.211
# step 2190: loss 0.209
# step 2200: loss 0.206
# step 2210: loss 0.204
# step 2220: loss 0.201
# step 2230: loss 0.199
# step 2240: loss 0.197
# step 2250: loss 0.194
# step 2260: loss 0.192
# step 2270: loss 0.189
# step 2280: loss 0.187
# step 2290: loss 0.185
# step 2300: loss 0.182
# step 2310: loss 0.181
# step 2320: loss 0.178
# step 2330: loss 0.176
# step 2340: loss 0.174
# step 2350: loss 0.173
# step 2360: loss 0.171
# step 2370: loss 0.168
# step 2380: loss 0.167
# step 2390: loss 0.165
# step 2400: loss 0.162
# step 2410: loss 0.160
# step 2420: loss 0.159
# step 2430: loss 0.157
# step 2440: loss 0.154
# step 2450: loss 0.154
# step 2460: loss 0.152
# step 2470: loss 0.149
# step 2480: loss 0.148
# step 2490: loss 0.146
# step 2500: loss 0.145
# step 2510: loss 0.143
# step 2520: loss 0.142
# step 2530: loss 0.140
# step 2540: loss 0.138
# step 2550: loss 0.136
# step 2560: loss 0.135
# step 2570: loss 0.134
# step 2580: loss 0.132
# step 2590: loss 0.131
# step 2600: loss 0.129
# step 2610: loss 0.128
# step 2620: loss 0.127
# step 2630: loss 0.126
# step 2640: loss 0.124
# step 2650: loss 0.123
# step 2660: loss 0.122
# step 2670: loss 0.120
# step 2680: loss 0.119
# step 2690: loss 0.118
# step 2700: loss 0.116
# step 2710: loss 0.115
# step 2720: loss 0.114
# step 2730: loss 0.113
# step 2740: loss 0.112
# step 2750: loss 0.111
# step 2760: loss 0.110
# step 2770: loss 0.109
# step 2780: loss 0.108
# step 2790: loss 0.107
# step 2800: loss 0.106
# step 2810: loss 0.105
# step 2820: loss 0.104
# step 2830: loss 0.103
# step 2840: loss 0.102
# step 2850: loss 0.100
# step 2860: loss 0.099
# step 2870: loss 0.098
# step 2880: loss 0.097
# step 2890: loss 0.096
# step 2900: loss 0.096
# step 2910: loss 0.095
# step 2920: loss 0.094
# step 2930: loss 0.093
# step 2940: loss 0.092
# step 2950: loss 0.091
# step 2960: loss 0.091
# step 2970: loss 0.090
# step 2980: loss 0.088
# step 2990: loss 0.088
# step 3000: loss 0.088
# step 3010: loss 0.086
# step 3020: loss 0.085
# step 3030: loss 0.085
# step 3040: loss 0.084
# step 3050: loss 0.084
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-2d6fa6cb4641> in <module>()
#       3                         siamese.x1: X[:,0,:],
#       4                         siamese.x2: X[:,1,:],
# ----> 5                         siamese.y_: y})
#       6
#       7     if np.isnan(loss_v):
#
# ~/.virtualenvs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.virtualenvs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~/.virtualenvs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.virtualenvs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/.virtualenvs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/.virtualenvs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
embed = siamese.o1.eval({siamese.x1: X_topic})

# %%
embed.shape
# Out:
# (3565, 3)

# %%
X_embedded = embed

# %%
X_embedded.shape
# Out:
# (3565, 3)

# %%
source = ColumnDataSource(data=dict(X=X_embedded[:, 0], Y=X_embedded[:, 1], labels=Y_topic, cat=X_categ))

# %%
hover = HoverTool(tooltips=[
    ("labels", "@labels"),
    ("cat", "@cat")
])

# %%
TOOLS="crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,"
p = figure(title='Diseases', tools=[hover, TOOLS], plot_width=600, plot_height=500)

# %%
palette = viridis(len(set(X_categ)))
color_map = CategoricalColorMapper(factors=list(set(X_categ)), palette=palette)

# %%
p.scatter(x='X', y='Y', color={'field': 'cat', 'transform': color_map}, source=source)
# Out:
# GlyphRenderer(id='ed40bb72-bb38-48c7-a57b-333c386ddeb5', ...)

# %%
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4d5945c9-ffc9-44fc-8837-c8e920b684bb"></div>
# </div>

# %% [markdown]
# ## Data for Dash

# %%
colors = viridis(len(set(X_categ)))
name2color_bokeh = {}
for i in list(set(X_categ)):
    name2color_bokeh[i] = colors[len(name2color_bokeh)]

# %%
vis_data = pd.DataFrame()
vis_data['name'] = Y_topic
vis_data['categ'] = X_categ
vis_data['X'] = X_embedded[:, 0]
vis_data['Y'] = X_embedded[:, 1]
vis_data['Z'] = X_embedded[:, 2]
vis_data['color'] = vis_data['categ'].apply(lambda x: name2color_bokeh[x])

# %%
vis_data.head()
# Out:
#                     name                 categ         X          Y         Z  \
# 0          Hallux valgus  Болезни ОДС и травмы -5.077133  -5.757468 -0.827155
# 1          HELLP-синдром       Женские болезни  3.681569 -12.854797 -3.708415
# 2  Абдоминальная мигрень       Нервные болезни  0.273175  -3.364479  6.766510
# 3    Абиотрофия сетчатки       Глазные болезни  6.142817  -2.510729  5.723158
# 4                 Абсанс       Нервные болезни -1.427816  -1.204047  6.859466
#
#      color
# 0  #443982
# 1  #460C5F
# 2  #BADE27
# 3  #462F7C
# 4  #BADE27

# %%
# vis_data.to_csv('vis_data_siamese_3d.csv', index=False)
